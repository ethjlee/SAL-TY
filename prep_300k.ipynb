# %%
import pandas as pd
import numpy as np

# %%
first_batch_coords = pd.read_csv("0-100k_data.csv")
second_batch_coords = pd.read_csv("100k-205k_data.csv")
all_data = pd.read_csv("1541875_locations_map.csv", header=None).iloc[:, :2]
all_data = pd.concat([all_data.index.to_frame(), all_data], axis=1)
all_data.columns = ['ID', 'X', 'Y']
first_batch_coords.columns = ['ID', 'X', 'Y']
second_batch_coords.columns = ['ID', 'X', 'Y']
print(first_batch_coords[:5])
print(second_batch_coords[:5])
print(all_data)
print(all_data.iloc[:5, :])
# Out:
#    ID          X           Y
# 0  21  32.977404 -115.637420
# 1  27  37.061908 -120.579161
# 2  35  38.545350 -120.746831
# 3  51  36.150854 -120.316000
# 4  73  34.198447 -118.390059
#    ID          X           Y
# 0  19  40.487453 -123.802673
# 1  26  36.952766 -120.297679
# 2  34  36.594277 -119.853882
# 3  52  32.642617 -116.776045
# 4  72  39.804619 -121.314720
#               ID          X           Y
# 0              0  36.159684 -120.085140
# 1              1  40.638961 -121.800011
# 2              2  38.857645 -121.656758
# 3              3  39.307691 -121.607290
# 4              4  38.852945 -121.451545
# ...          ...        ...         ...
# 1541870  1541870  36.199349 -119.820705
# 1541871  1541871  38.984047 -122.600998
# 1541872  1541872  33.066854 -116.814961
# 1541873  1541873  38.413930 -121.400952
# 1541874  1541874  38.540297 -122.858903
#
# [1541875 rows x 3 columns]
#    ID          X           Y
# 0   0  36.159684 -120.085140
# 1   1  40.638961 -121.800011
# 2   2  38.857645 -121.656758
# 3   3  39.307691 -121.607290
# 4   4  38.852945 -121.451545

# %%
completed = pd.concat([first_batch_coords, second_batch_coords], axis=0)
completed = completed.sort_values(by='ID')
completed = completed.reset_index(drop=True)
print(completed)
# Out:
#              ID          X           Y
# 0            19  40.487453 -123.802673
# 1            21  32.977404 -115.637420
# 2            26  36.952766 -120.297679
# 3            27  37.061908 -120.579161
# 4            34  36.594277 -119.853882
# ...         ...        ...         ...
# 204995  1541840  33.688971 -117.359605
# 204996  1541844  36.109064 -119.901142
# 204997  1541849  34.796609 -120.440464
# 204998  1541856  36.728407 -119.585458
# 204999  1541857  39.267285 -121.412235
#
# [205000 rows x 3 columns]

# %%
mask = all_data.index.isin(completed.iloc[:, 0])
#print(mask)
new_data = all_data[~mask]
print(new_data)

assert(new_data.shape[0] == all_data.shape[0] - completed.shape[0])
# Out:
#               ID          X           Y
# 0              0  36.159684 -120.085140
# 1              1  40.638961 -121.800011
# 2              2  38.857645 -121.656758
# 3              3  39.307691 -121.607290
# 4              4  38.852945 -121.451545
# ...          ...        ...         ...
# 1541870  1541870  36.199349 -119.820705
# 1541871  1541871  38.984047 -122.600998
# 1541872  1541872  33.066854 -116.814961
# 1541873  1541873  38.413930 -121.400952
# 1541874  1541874  38.540297 -122.858903
#
# [1336875 rows x 3 columns]

# %%
#old seed = 47293
rng = np.random.default_rng(86731)
print(new_data.index.dtype)
selection = rng.choice(new_data.index.values, size=95000, replace=False)

print(len(selection))
print(selection)
# Out:
# int64
# 95000
# [1122446   47135 1158900 ...   42296  900432 1096564]

# %%
new_data = new_data.loc[selection].sort_index()
print(new_data.shape)
print(new_data)
# Out:
# (95000, 3)
#               ID          X           Y
# 1              1  40.638961 -121.800011
# 6              6  32.685764 -116.065506
# 18            18  34.425895 -119.625891
# 48            48  35.252848 -119.259755
# 50            50  39.665748 -121.007384
# ...          ...        ...         ...
# 1541774  1541774  38.776601 -120.463088
# 1541795  1541795  38.041847 -122.684430
# 1541820  1541820  40.807843 -124.118110
# 1541837  1541837  36.131378 -121.129086
# 1541865  1541865  33.707998 -116.871064
#
# [95000 rows x 3 columns]

# %%
new_data.to_csv("205k-300k_data.csv", index=False)
