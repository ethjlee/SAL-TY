# %%
import pandas as pd 
import numpy as np

# %%
map_path = "1541875_locations_map.csv"
map = pd.read_csv(map_path, header=None)
map = map.loc[:, :1]
print(map)
# Out:
#                  0           1
# 0        36.159684 -120.085140
# 1        40.638961 -121.800011
# 2        38.857645 -121.656758
# 3        39.307691 -121.607290
# 4        38.852945 -121.451545
# ...            ...         ...
# 1541870  36.199349 -119.820705
# 1541871  38.984047 -122.600998
# 1541872  33.066854 -116.814961
# 1541873  38.413930 -121.400952
# 1541874  38.540297 -122.858903
#
# [1541875 rows x 2 columns]

# %%
rng = np.random.default_rng(47293)

selection = rng.choice(map.shape[0], 100000, replace=False)

print(selection)
print(len(selection))
print(len(np.unique(selection)) == len(selection), "unique elements")
# Out:
# [1101140  329462   96566 ...  773482 1478784 1532352]
# 100000
# True unique elements

# %%
final_data = map.loc[selection].sort_index()
print(final_data)
# Out:
#                  0           1
# 21       32.977404 -115.637420
# 27       37.061908 -120.579161
# 35       38.545350 -120.746831
# 51       36.150854 -120.316000
# 73       34.198447 -118.390059
# ...            ...         ...
# 1541758  39.535184 -121.155043
# 1541840  33.688971 -117.359605
# 1541844  36.109064 -119.901142
# 1541856  36.728407 -119.585458
# 1541857  39.267285 -121.412235
#
# [100000 rows x 2 columns]

# %% [markdown]
# ## Output of final results, re-check all rejects

# %%
completed_df = pd.read_csv("completed_backup.csv")
completed_df_2 = pd.read_csv("completed_75000.csv")

print(completed_df_2)
# Out:
#                         timestamp    index                  panoid        lat  \
# 0      2026-02-13T04:52:59.216369  1156537  8A3RHOhHov6Q49pDf1z73Q  38.935729
# 1      2026-02-13T04:53:02.023195  1156575  yAN_rJbdFFyqCzhIyCXyOA  37.342290
# 2      2026-02-13T04:53:05.088410  1156592  DYCnb0o2XFNfd7gAjDnvzQ  35.025927
# 3      2026-02-13T04:53:07.895830  1156608  lYfXdFLPG8aJuDkxAcLADw  39.589290
# 4      2026-02-13T04:53:10.570160  1156611  wjrb2K9ed30BF09XWBfbPw  39.962722
# ...                           ...      ...                     ...        ...
# 24990  2026-02-14T04:26:20.902262  1541758  1FGrVqRO0FdsrmprF0Rn8w  39.535184
# 24991  2026-02-14T04:26:23.771269  1541840  VBO4kbbyJXPR-Mwv8-2xXw  33.688971
# 24992  2026-02-14T04:26:26.950123  1541844  BgdOQ0f8YJ2HW0R0w3EoXQ  36.109064
# 24993  2026-02-14T04:26:30.149287  1541856  YO4wkjY1fFNMDd4uIQ9j_g  36.728407
# 24994  2026-02-14T04:26:33.107917  1541857  b3aK75IvvmOMhZ7W4WKlHw  39.267285
#
#               lon
# ...

# %%
merged_completed = pd.merge(completed_df, completed_df_2, how='outer')
merged_completed.sort_values(by='index', axis=0)
# Out:
#                         timestamp    index                  panoid        lat  \
# 0      2026-02-09T07:32:18.401406       21  e9SG39QTyDkBf652W7QRzw  32.977404
# 1      2026-02-09T07:32:23.155746       27  GAngkU1iYOZ9WfzMEc1QVg  37.061908
# 2      2026-02-09T07:32:28.027367       35  uqLbgksO3o4M4KU4gRaxfw  38.545350
# 3      2026-02-09T07:32:32.631694       51  JqNMPBeaZhUlCe8dI6mJrA  36.150854
# 4      2026-02-09T07:32:36.036507       73  31cU5A3kY2xaHw3d5SfgZg  34.198447
# ...                           ...      ...                     ...        ...
# 96557  2026-02-14T04:26:20.902262  1541758  1FGrVqRO0FdsrmprF0Rn8w  39.535184
# 96559  2026-02-14T04:26:23.771269  1541840  VBO4kbbyJXPR-Mwv8-2xXw  33.688971
# 96562  2026-02-14T04:26:26.950123  1541844  BgdOQ0f8YJ2HW0R0w3EoXQ  36.109064
# 96564  2026-02-14T04:26:30.149287  1541856  YO4wkjY1fFNMDd4uIQ9j_g  36.728407
# 96566  2026-02-14T04:26:33.107917  1541857  b3aK75IvvmOMhZ7W4WKlHw  39.267285
#
#               lon
# ...

# %%
merged_completed = merged_completed.to_csv("completed_100000.csv")
